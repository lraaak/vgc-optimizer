# %%
import sys
import pandas as pd

# %%
sys.path.append('../src')
from data_loader import PokemonDataLoader

loader = PokemonDataLoader(raw_data_dir="../data/raw")

df = loader.build_base_dataset()

display(df.head())
# Out:
# Fetching base list of 1025 Pokémon...
# Fetching alternate varieties (Megas, Regionals, Forms)...
# Processing 0/1025...
# Processing 50/1025...
# Processing 100/1025...
# Processing 150/1025...
# Processing 200/1025...
# Processing 250/1025...
# Processing 300/1025...
# Processing 350/1025...
# Processing 400/1025...
# Processing 450/1025...
# Processing 500/1025...
# Processing 550/1025...
# Processing 600/1025...
# Processing 650/1025...
# Processing 700/1025...
# Processing 750/1025...
# Processing 800/1025...
# Processing 850/1025...
# Processing 900/1025...
# Processing 950/1025...
# Processing 1000/1025...
# Dataset saved to ../data/raw/base_pokemon_data.csv. Total unique forms: 1025
#    id        name type_1  type_2 ability_1    ability_2 hidden_ability  hp  \
# 0   1   bulbasaur  grass  poison  overgrow  chlorophyll           None  45
# 1   2     ivysaur  grass  poison  overgrow  chlorophyll           None  60
# ...
