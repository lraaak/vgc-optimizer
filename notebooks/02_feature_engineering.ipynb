# %%
import sys
import pandas as pd

# %%
sys.path.append('../src')
from feature_engineering import PokemonFeatureEngineer

engineer = PokemonFeatureEngineer()
df_engineered = engineer.run_pipeline()

display(df_engineered[['name', 'physical_bulk', 'special_bulk', 'speed_tier', 'bst_efficiency']].head())
# Out:
# Loading base data...
# Engineering ML features...
# Pipeline complete. Saved to ../data/processed/engineered_pokemon_data.csv
#          name  physical_bulk  special_bulk  speed_tier  bst_efficiency
# 0   bulbasaur           2205          2925           0             1.0
# 1     ivysaur           3780          4800           1             1.0
# 2    venusaur           6640          8000           2             1.0
# 3  charmander           1677          1950           1             1.0
# 4  charmeleon           3364          3770           2             1.0
