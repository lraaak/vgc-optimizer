# %%
import sys
sys.path.append('../src')
from synergy_scorer import TeamSynergyScorer

# %%
scorer = TeamSynergyScorer()

sample_team = ['incineroar', 'rillaboom', 'flutter-mane', 'urshifu-rapid-strike']

synergy_scores = scorer.score_team(sample_team)
print(synergy_scores)
# Out:
# {'team': ['incineroar', 'rillaboom', 'flutter-mane', 'urshifu-rapid-strike'], 'severe_weakness_overlaps': 0, 'role_balance_score': 0.75, 'speed_variance': 1.0897247358851685, 'average_bst_efficiency': 0.8812030934970358}
